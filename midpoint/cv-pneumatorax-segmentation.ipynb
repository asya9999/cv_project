train_0_.png  1.2.276.0.7230010.3.1.4.8323329.10206.15178752...
#
#     has_pneumo
# 0            0
# 1            0
# 2            1
# 3            1
# 4            1
# 5            0
# 6            0
# 7            1
# 8            1
# 9            0
# 10           1
# 11           1
# 12           0
# 13           1
# 14           0

# %%
sns.set_palette("Greys")

train_df_with_pneumo = train_df[train_df['has_pneumo'] == 1]
train_df_without_pneumo = train_df[train_df['has_pneumo'] == 0]

plt.title("TRAIN. Number of images with and without pneumothorax")
sns.barplot(x=["has_pneumo", "has_no_pneumo"], y = [len(train_df_with_pneumo), len(train_df_without_pneumo)])
plt.ylabel("# of images")
# Out:
# Text(0, 0.5, '# of images')

# %%
train_df_with_pneumo = train_df[train_df['has_pneumo'] == 1]
#train_df_without_pneumo = train_df[train_df['has_pneumo'] == 0][:len(train_df_with_pneumo)]
train_df_without_pneumo = train_df[train_df['has_pneumo'] == 0][:300]

plt.title("TRAIN. Number of images with and without pneumothorax")
sns.barplot(x=["has_pneumo", "has_no_pneumo"], y = [len(train_df_with_pneumo), len(train_df_without_pneumo)])
plt.ylabel("# of images")
# Out:
# Text(0, 0.5, '# of images')

# %%
test_df_with_pneumo = test_df[test_df['has_pneumo'] == 1]
test_df_without_pneumo = test_df[test_df['has_pneumo'] == 0]


plt.title("TEST. Number of images with and without pneumothorax")
sns.barplot(x=["has_pneumo", "has_no_pneumo"], y = [len(test_df_with_pneumo), len(test_df_without_pneumo)])
plt.ylabel("# of images")
# Out:
# Text(0, 0.5, '# of images')

# %%
test_df_with_pneumo = test_df[test_df['has_pneumo'] == 1]
#test_df_without_pneumo = test_df[test_df['has_pneumo'] == 0][:len(test_df_with_pneumo)]

test_df_without_pneumo = test_df[test_df['has_pneumo'] == 0][:30]

plt.title("TEST. Number of images with and without pneumothorax")
sns.barplot(x=["has_pneumo", "has_no_pneumo"], y = [len(test_df_with_pneumo), len(test_df_without_pneumo)])
plt.ylabel("# of images")
# Out:
# Text(0, 0.5, '# of images')

# %%
from tqdm import tqdm 
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
import cv2
N_CHANNELS = 3

# Create X_train, Y_train, and Label 
train_size = len(train_df_with_pneumo + train_df_without_pneumo)

X_train = np.zeros((train_size, IMG_SIZE, IMG_SIZE, N_CHANNELS))
Y_train = np.zeros((train_size, IMG_SIZE, IMG_SIZE, 1), dtype=np.bool)
labels = np.zeros(train_size, dtype=np.uint8)

img_data = list( pd.concat([train_df_with_pneumo, train_df_without_pneumo]).T.to_dict().values())


for i, data_row in tqdm(enumerate(img_data), total=len(img_data)):
    
    patientImage = data_row['new_filename']
    imageLabel  = data_row['has_pneumo']

    lungImage = imread(os.path.join(img_path, patientImage))
    lungImage = np.expand_dims(resize(lungImage, (IMG_SIZE, IMG_SIZE), mode='constant', preserve_range=True), axis=-1)
    #normalizedImg = lungImage/255
    norm_img = np.zeros((IMG_SIZE,IMG_SIZE))
    norm_img = cv2.normalize(lungImage,  norm_img, 0, 255, cv2.NORM_MINMAX)
    img2 = cv2.merge((norm_img,norm_img,norm_img))
    
    X_train[i] = img2/255

    labels[i] = imageLabel

    maskImage = imread(os.path.join(mask_path, patientImage))
    maskImage = np.expand_dims(resize(maskImage, (IMG_SIZE, IMG_SIZE), mode='constant', preserve_range=True), axis=-1)
    maskImage = maskImage/255
    Y_train[i] = maskImage
# Out:
# 100%|██████████| 2679/2679 [04:21<00:00, 10.23it/s]

# %%
#X_train[:, :, :]/=255

print(max(X_train[1].flatten()))
# Out:
# 1.0000000000000002

# %%
plt.imshow(X_train[0]/255)

# %%
print(X_train.shape)
# Out:
# (2679, 128, 128, 3)

# %%
# Illustrate the train images and masks
plt.figure(figsize=(20, 16))
x, y = 12, 4

for i in range(y):
    for j in range(x):
        plt.subplot(y*2, x, i*2*x+j+1)
        pos = i*120 + j*10
        plt.imshow(X_train[pos])
        plt.title('Image')
        plt.axis('off')
        plt.subplot(y*2, x, (i*2+1)*x+j+1)

        plt.imshow(np.squeeze(Y_train[pos]), cmap='gray_r')
        plt.title('Mask\nLabel: {}'.format(labels[pos]))
        plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import keras.backend as K
from keras.engine import Layer

from keras.models import Sequential,Model
from keras.layers import Input, Dropout, merge
from keras.layers.convolutional import Convolution2D, UpSampling2D, ZeroPadding2D, Cropping2D, Deconvolution2D
from keras.layers.core import Activation
from keras.optimizers import Adam, SGD

from keras.applications.resnet50 import ResNet50
from keras.models import Model, load_model
from keras.metrics import binary_accuracy

import numpy as np
import tensorflow as tf

import gc
gc.collect()
# Out:
# 22

# %%
value_dict = {1: False,
              0: True,
              }

def rgb_to_onehot(rgb_arr, value_dict):
    
    print(rgb_arr.shape)
    
    num_classes = len(value_dict)
    shape = rgb_arr.shape[:3]+(num_classes,)
    
    #print(shape)
    arr = np.zeros( shape, dtype=np.int8 )
    

    for i, cls in enumerate(value_dict):
        #print(np.all(rgb_arr.reshape( (-1,1) ) == value_dict[i], axis=1).reshape(shape[:3]))
        arr[:,:,:,i] = np.all(rgb_arr.reshape( (-1,1) ) == value_dict[i], axis=1).reshape(shape[:3])
    return arr

new_Y = rgb_to_onehot(Y_train, value_dict)
new_Y = 1*np.array(new_Y, dtype="bool")


def onehot_to_rgb(onehot):
    
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(1,) )
    
    for i in range(output.shape[0]):
        for k in range(output.shape[1]):
            #if onehot[i, k , 0] >onehot[i, k , 1]:
            if onehot[i, k , 0] >onehot[i, k , 1]:
                output[i, k] = 0
            else:
                output[i, k] = 1
    
    

    return np.uint8(output)
# Out:
# (2679, 128, 128, 1)

# %%
#Model parameters
stride = 32
learning_rate = 0.1
N_CLASSES = 2
batch_size = 2
N_epochs = 30

# Init the VGG model
vgg_conv = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
for layer in vgg_conv.layers[:]:
    layer.trainable = False

# ENCODER
# Create the model based /on VGG16
model_with_vgg = Sequential()
model_with_vgg.add(vgg_conv)

# add classifier - to get size down to at most 8x8
model_with_vgg.add(Dropout(0.2))
#model_with_vgg.add(Convolution2D(256,kernel_size=(1,1),padding = "same",activation = "relu",name = "fc6"))
#model_with_vgg.add(Dropout(0.5))
#model_with_vgg.add(Convolution2D(N_CLASSES,kernel_size=(1,1),padding="same",activation="relu",name = "score_fr"))
    
model_with_vgg.add(Convolution2D(128,1,1,name = 'pred_33'))

# Upsampling


model_with_vgg.add(Deconvolution2D(N_CLASSES, (16, 16), strides=(stride, stride), padding='same') )

model_with_vgg.add(Activation('softmax'))
model_with_vgg.summary()        


opt = tf.keras.layers.LeakyReLU()
m = tf.keras.metrics.MeanIoU(num_classes=2)

model_with_vgg.compile(loss="categorical_crossentropy",
              optimizer="Adam",
              metrics=['accuracy'])

# %%
model_with_vgg.fit(
    X_train, new_Y,
    validation_split=0.1,
    batch_size = batch_size,
    epochs = N_epochs
)

# %%
#Model parameters
stride = 32
learning_rate = 0.1
N_CLASSES = 2
batch_size = 2
N_epochs = 30

# Init the VGG model
resnet_conv = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
for layer in resnet_conv.layers[:]:
    layer.trainable = False

# ENCODER
# Create the model based /on VGG16
model_with_resnet = Sequential()
model_with_resnet.add(resnet_conv)

# add classifier - to get size down to at most 8x8
model_with_resnet.add(Dropout(0.2))
model_with_resnet.add(Convolution2D(128,1,1))    
model_with_resnet.add(Convolution2D(32,1,1,))

# Upsampling

model_with_resnet.add(Deconvolution2D(N_CLASSES, (4, 4), strides=(4, 4), padding='same') )

model_with_resnet.add(Deconvolution2D(N_CLASSES, (4, 4), strides=(4, 4), padding='same') )

model_with_resnet.add(Deconvolution2D(N_CLASSES, (2, 2), strides=(2, 2), padding='same') )


model_with_resnet.add(Activation('softmax'))
model_with_resnet.summary()        

m = tf.keras.metrics.MeanIoU(num_classes=2)

model_with_resnet.compile(loss="categorical_crossentropy",
              optimizer="SGD",
              metrics=['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 2048)        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 4, 4, 128)         262272
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 32)          4128
# _________________________________________________________________
# conv2d_transpose_9 (Conv2DTr (None, 16, 16, 2)         1026
# _________________________________________________________________
# conv2d_transpose_10 (Conv2DT (None, 64, 64, 2)         66
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 128, 128, 2)       18
# _________________________________________________________________
# activation_3 (Activation)    (None, 128, 128, 2)       0
# =================================================================
# Total params: 23,855,222
# Trainable params: 267,510
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model_with_resnet.fit(
    X_train, new_Y,
    validation_split=0.1,
    batch_size = batch_size,
    epochs = N_epochs
)
# Out:
# Epoch 1/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.1003 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 2/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.1001 - accuracy: 0.9791 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 3/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0999 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 4/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0997 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 5/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0994 - accuracy: 0.9791 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 6/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0992 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 7/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0989 - accuracy: 0.9791 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 8/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0985 - accuracy: 0.9791 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 9/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0981 - accuracy: 0.9791 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 10/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0977 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 11/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0973 - accuracy: 0.9791 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 12/30
# 1206/1206 [==============================] - 15s 13ms/step - loss: 0.0969 - accuracy: 0.9791 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 13/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0964 - accuracy: 0.9791 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 14/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0961 - accuracy: 0.9791 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 15/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0956 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 16/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0952 - accuracy: 0.9791 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 17/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0949 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 18/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0947 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 19/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0942 - accuracy: 0.9791 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 20/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0940 - accuracy: 0.9791 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 21/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0937 - accuracy: 0.9791 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 22/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0935 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 23/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0933 - accuracy: 0.9791 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 24/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0932 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 25/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0929 - accuracy: 0.9791 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 26/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0927 - accuracy: 0.9791 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 27/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0925 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 28/30
# 1206/1206 [==============================] - 14s 12ms/step - loss: 0.0924 - accuracy: 0.9791 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 29/30
# 1206/1206 [==============================] - 15s 13ms/step - loss: 0.0921 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 30/30
# 1206/1206 [==============================] - 15s 12ms/step - loss: 0.0919 - accuracy: 0.9791 - val_loss: 0.0204 - val_accuracy: 1.0000

# %%
res = onehot_to_rgb(model_with_resnet.predict(X_train[0:6])[1] )
plt.imshow(res.reshape( (128,128) ))

# %%
from tqdm import tqdm 
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
import cv2
N_CHANNELS = 3

# Create X_train, Y_train, and Label 
train_size = len(test_df_with_pneumo)

X_test = np.zeros((train_size, IMG_SIZE, IMG_SIZE, N_CHANNELS))
Y_test = np.zeros((train_size, IMG_SIZE, IMG_SIZE, 1), dtype=np.bool)
labels_test = np.zeros(train_size, dtype=np.uint8)

img_data = list( test_df_with_pneumo.T.to_dict().values())


for i, data_row in tqdm(enumerate(img_data), total=len(img_data)):
    
    patientImage = data_row['new_filename']
    imageLabel  = data_row['has_pneumo']

    lungImage = imread(os.path.join(img_path, patientImage))
    lungImage = np.expand_dims(resize(lungImage, (IMG_SIZE, IMG_SIZE), mode='constant', preserve_range=True), axis=-1)
    #normalizedImg = lungImage/255
    norm_img = np.zeros((IMG_SIZE,IMG_SIZE))
    norm_img = cv2.normalize(lungImage,  norm_img, 0, 255, cv2.NORM_MINMAX)
    img2 = cv2.merge((norm_img,norm_img,norm_img))
    
    X_test[i] = img2/255

    labels_test[i] = imageLabel

    maskImage = imread(os.path.join(mask_path, patientImage))
    maskImage = np.expand_dims(resize(maskImage, (IMG_SIZE, IMG_SIZE), mode='constant', preserve_range=True), axis=-1)
    maskImage = maskImage/255
    Y_test[i] = maskImage
# Out:
# 100%|██████████| 290/290 [00:27<00:00, 10.52it/s]

# %%
print(dir(tf.keras.applications))
# Out:
# ['DenseNet121', 'DenseNet169', 'DenseNet201', 'InceptionResNetV2', 'InceptionV3', 'MobileNet', 'MobileNetV2', 'NASNetLarge', 'NASNetMobile', 'ResNet101', 'ResNet101V2', 'ResNet152', 'ResNet152V2', 'ResNet50', 'ResNet50V2', 'VGG16', 'VGG19', 'Xception', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_sys', 'densenet', 'imagenet_utils', 'inception_resnet_v2', 'inception_v3', 'mobilenet', 'mobilenet_v2', 'nasnet', 'resnet', 'resnet50', 'resnet_v2', 'vgg16', 'vgg19', 'xception']

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.keras.applications import InceptionV3

#Model parameters
stride = 32
learning_rate = 0.1
N_CLASSES = 2
batch_size = 2
N_epochs = 30

# Init the VGG model
efnet_conv = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
for layer in efnet_conv.layers[:]:
    layer.trainable = False

# ENCODER
# Create the model based /on VGG16
model_with_efnet = Sequential()
model_with_efnet.add(efnet_conv)

# add classifier - to get size down to at most 8x8
model_with_efnet.add(Dropout(0.2))
model_with_efnet.add(Convolution2D(128,1,1))    
model_with_efnet.add(Convolution2D(32,1,1,))

# Upsampling

model_with_efnet.add(Deconvolution2D(N_CLASSES, (4, 4), strides=(4, 4), padding='same') )

model_with_efnet.add(Deconvolution2D(N_CLASSES, (4, 4), strides=(4, 4), padding='same') )

model_with_efnet.add(Deconvolution2D(N_CLASSES, (2, 2), strides=(2, 2), padding='same') )


model_with_efnet.add(Deconvolution2D(N_CLASSES, (2, 2), strides=(2, 2), padding='same') )



model_with_efnet.add(Activation('softmax'))
model_with_efnet.summary()        

m = tf.keras.metrics.MeanIoU(num_classes=2)

model_with_efnet.compile(loss="categorical_crossentropy",
              optimizer="SGD",
              metrics=['accuracy'])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 2, 2, 2048)        21802784
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 2048)        0
# _________________________________________________________________
# conv2d_192 (Conv2D)          (None, 2, 2, 128)         262272
# _________________________________________________________________
# conv2d_193 (Conv2D)          (None, 2, 2, 32)          4128
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 8, 8, 2)           1026
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 32, 32, 2)         66
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 64, 64, 2)         18
# _________________________________________________________________
# conv2d_transpose_18 (Conv2DT (None, 128, 128, 2)       18
# _________________________________________________________________
# activation_193 (Activation)  (None, 128, 128, 2)       0
# =================================================================
# Total params: 22,070,312
# Trainable params: 267,528
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_with_efnet.fit(
    X_train, new_Y,
    validation_split=0.1,
    batch_size = batch_size,
    epochs = N_epochs
)
# Out:
# Epoch 1/30
# 1206/1206 [==============================] - 24s 20ms/step - loss: 0.1947 - accuracy: 0.9773 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 2/30
# 1206/1206 [==============================] - 23s 19ms/step - loss: 0.1071 - accuracy: 0.9791 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 3/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1028 - accuracy: 0.9791 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 4/30
# 1206/1206 [==============================] - 22s 19ms/step - loss: 0.1020 - accuracy: 0.9791 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 5/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1017 - accuracy: 0.9791 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 6/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1016 - accuracy: 0.9791 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 7/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1016 - accuracy: 0.9791 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 8/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1015 - accuracy: 0.9791 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 9/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1015 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 10/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1015 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 11/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1014 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 12/30
# 1206/1206 [==============================] - 22s 19ms/step - loss: 0.1014 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 13/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1014 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 14/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1014 - accuracy: 0.9791 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 15/30
# 1206/1206 [==============================] - 22s 18ms/step - loss: 0.1014 - accuracy: 0.9791 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 17/30
#  987/1206 [=======================>......] - ETA: 3s - loss: 0.1017 - accuracy: 0.9790
